# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection  import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import f1_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# ### Data Exploration:

# %%
tele = pd.read_csv('./dataset/Churn.csv')

# %%
tele.head()
# Out:
#    Account_Length  Vmail_Message  Day_Mins  Eve_Mins  Night_Mins  Intl_Mins  \
# 0             128             25     265.1     197.4       244.7       10.0
# 1             107             26     161.6     195.5       254.4       13.7
# 2             137              0     243.4     121.2       162.6       12.2
# 3              84              0     299.4      61.9       196.9        6.6
# 4              75              0     166.7     148.3       186.9       10.1
#
#    CustServ_Calls Churn Intl_Plan Vmail_Plan  ...  Day_Charge  Eve_Calls  \
# 0               1    no        no        yes  ...       45.07         99
# 1               1    no        no        yes  ...       27.47        103
# 2               0    no        no         no  ...       41.38        110
# 3               2    no       yes         no  ...       50.90         88
# 4               3    no       yes         no  ...       28.34        122
#
#    Eve_Charge  Night_Calls  Night_Charge  Intl_Calls  Intl_Charge  State  \
# 0       16.78           91         11.01           3         2.70     KS
# 1       16.62          103         11.45           3         3.70     OH
# 2       10.30          104          7.32           5         3.29     NJ
# 3        5.26           89          8.86           7         1.78     OH
# 4       12.61          121          8.41           3         2.73     OK
#
#   Area_Code     Phone
# 0       415  382-4657
# 1       415  371-7191
# 2       415  358-1921
# 3       408  375-9999
# 4       415  330-6626
#
# [5 rows x 21 columns]

# %%
tele.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Account_Length  3333 non-null   int64
#  1   Vmail_Message   3333 non-null   int64
#  2   Day_Mins        3333 non-null   float64
#  3   Eve_Mins        3333 non-null   float64
#  4   Night_Mins      3333 non-null   float64
#  5   Intl_Mins       3333 non-null   float64
#  6   CustServ_Calls  3333 non-null   int64
#  7   Churn           3333 non-null   object
#  8   Intl_Plan       3333 non-null   object
#  9   Vmail_Plan      3333 non-null   object
#  10  Day_Calls       3333 non-null   int64
#  11  Day_Charge      3333 non-null   float64
#  12  Eve_Calls       3333 non-null   int64
#  13  Eve_Charge      3333 non-null   float64
#  14  Night_Calls     3333 non-null   int64
#  15  Night_Charge    3333 non-null   float64
#  16  Intl_Calls      3333 non-null   int64
#  17  Intl_Charge     3333 non-null   float64
#  18  State           3333 non-null   object
#  19  Area_Code       3333 non-null   int64
#  20  Phone           3333 non-null   object
# dtypes: float64(8), int64(8), object(5)
# memory usage: 546.9+ KB

# %%
tele.describe()
# Out:
#        Account_Length  Vmail_Message     Day_Mins     Eve_Mins   Night_Mins  \
# count     3333.000000    3333.000000  3333.000000  3333.000000  3333.000000
# mean       101.064806       8.099010   179.775098   200.980348   200.872037
# std         39.822106      13.688365    54.467389    50.713844    50.573847
# min          1.000000       0.000000     0.000000     0.000000    23.200000
# 25%         74.000000       0.000000   143.700000   166.600000   167.000000
# 50%        101.000000       0.000000   179.400000   201.400000   201.200000
# 75%        127.000000      20.000000   216.400000   235.300000   235.300000
# max        243.000000      51.000000   350.800000   363.700000   395.000000
#
#          Intl_Mins  CustServ_Calls    Day_Calls   Day_Charge    Eve_Calls  \
# count  3333.000000     3333.000000  3333.000000  3333.000000  3333.000000
# mean     10.237294        1.562856   100.435644    30.562307   100.114311
# std       2.791840        1.315491    20.069084     9.259435    19.922625
# min       0.000000        0.000000     0.000000     0.000000     0.000000
# 25%       8.500000        1.000000    87.000000    24.430000    87.000000
# 50%      10.300000        1.000000   101.000000    30.500000   100.000000
# 75%      12.100000        2.000000   114.000000    36.790000   114.000000
# max      20.000000        9.000000   165.000000    59.640000   170.000000
#
#         Eve_Charge  Night_Calls  Night_Charge   Intl_Calls  Intl_Charge  \
# count  3333.000000  3333.000000   3333.000000  3333.000000  3333.000000
# mean     17.083540   100.107711      9.039325     4.479448     2.764581
# std       4.310668    19.568609      2.275873     2.461214     0.753773
# min       0.000000    33.000000      1.040000     0.000000     0.000000
# 25%      14.160000    87.000000      7.520000     3.000000     2.300000
# 50%      17.120000   100.000000      9.050000     4.000000     2.780000
# 75%      20.000000   113.000000     10.590000     6.000000     3.270000
# max      30.910000   175.000000     17.770000    20.000000     5.400000
#
#          Area_Code
# count  3333.000000
# mean    437.182418
# std      42.371290
# min     408.000000
# 25%     408.000000
# 50%     415.000000
# 75%     510.000000
# max     510.000000

# %% [markdown]
# let us comment about each data set columns:
#
# ###### Account_Lenght(integer type): this containts the number of days from went the account was started until now. the average is 101 days.
# ###### Vmail_messages(interger type): this is the number of messages using vmail service we can see that more than have of the users don't use this service.
# ###### Day_Mins(float type) : number of minutes in the day time
# ###### Eve_Mins(float type) : number of minutes in the evening time
# ###### Night_Mins(float type) : number of minutes in the night time
# ###### Int_Mins (float type): number of minutes using international calls service
# ###### CustServ_calls (interger type): costumer services calls number avg is 1.5 overall
# ###### Intl_Plan (object --> Boolean): international plans yes or no should be changed to 1s and 0s
# ###### Vmail_Plan (object --> Boolean) : vmail plan yes or no this should also be changed to 1s and 0s
# ###### Day_Calls (Integers) : number of calls per days.
# ###### Day_Charge (float): the charges incurred by a customer for their usage during the day.
# ###### Eve_Calls(Integers) :   number of calls per evening.
# ###### Eve_Charge(float) : the charges incurred by a customer for their usage during the Evening.
# ###### Night_Calls (Integerd) : number of calls per Night.
# ###### Night_Charge (float): the charges incurred by a customer for their usage during the Night.
# ###### Intl_Calls   (Intergerd): number of international calls.
# ###### Intl_Charge  (float): the charges incurred by a customer for their international usage
# ###### State (String) : state of the user
# ###### Area_Code (Interger) :  user area code
# ###### Phone (String) : user phone call

# %%
tele.isnull().sum()
# Out:
# Account_Length    0
# Vmail_Message     0
# Day_Mins          0
# Eve_Mins          0
# Night_Mins        0
# Intl_Mins         0
# CustServ_Calls    0
# Churn             0
# Intl_Plan         0
# Vmail_Plan        0
# Day_Calls         0
# Day_Charge        0
# Eve_Calls         0
# Eve_Charge        0
# Night_Calls       0
# Night_Charge      0
# Intl_Calls        0
# Intl_Charge       0
# State             0
# Area_Code         0
# Phone             0
# dtype: int64

# %% [markdown]
# #### there is no missing data.

# %%
tele['Churn'].value_counts()
# Out:
# no     2850
# yes     483
# Name: Churn, dtype: int64

# %%
tele.groupby(['Churn']).mean()
# Out:
#        Account_Length  Vmail_Message    Day_Mins    Eve_Mins  Night_Mins  \
# Churn
# no         100.793684       8.604561  175.175754  199.043298  200.133193
# yes        102.664596       5.115942  206.914079  212.410145  205.231677
#
#        Intl_Mins  CustServ_Calls   Day_Calls  Day_Charge   Eve_Calls  \
# Churn
# no     10.158877        1.449825  100.283158   29.780421  100.038596
# yes    10.700000        2.229814  101.335404   35.175921  100.561077
#
#        Eve_Charge  Night_Calls  Night_Charge  Intl_Calls  Intl_Charge  \
# Churn
# no      16.918909   100.058246      9.006074    4.532982     2.743404
# yes     18.054969   100.399586      9.235528    4.163561     2.889545
#
#         Area_Code
# Churn
# no     437.074737
# yes    437.817805

# %%
tele.groupby(['Churn']).std()
# Out:
#        Account_Length  Vmail_Message   Day_Mins   Eve_Mins  Night_Mins  \
# Churn
# no           39.88235      13.913125  50.181655  50.292175   51.105032
# yes          39.46782      11.860138  68.997792  51.728910   47.132825
#
#        Intl_Mins  CustServ_Calls  Day_Calls  Day_Charge  Eve_Calls  \
# Churn
# no      2.784489        1.163883  19.801157    8.530835  19.958414
# yes     2.793190        1.853275  21.582307   11.729710  19.724711
#
#        Eve_Charge  Night_Calls  Night_Charge  Intl_Calls  Intl_Charge  \
# Churn
# no       4.274863    19.506246      2.299768    2.441984     0.751784
# yes      4.396762    19.950659      2.121081    2.551575     0.754152
#
#        Area_Code
# Churn
# no     42.306156
# yes    42.792270

# %%
tele.groupby('State')['Churn'].value_counts()
# Out:
# State  Churn
# AK     no       49
#        yes       3
# AL     no       72
#        yes       8
# AR     no       44
#                 ..
# WI     yes       7
# WV     no       96
#        yes      10
# WY     no       68
#        yes       9
# Name: Churn, Length: 102, dtype: int64

# %% [markdown]
# ##### we can see states  are very important to determing wether s customer will or not cancel there service.

# %%
for col in tele.columns[:-1]:
    sns.displot(tele[col])
    plt.show()

# %%
import seaborn as sns
import pandas as pd

for col in tele.select_dtypes(include='number').columns:
    sns.boxplot(x='Churn', y=col, data=tele)
    plt.show()

# %%
#extract columns having data type as object (i.e non numeric)
for col in tele:
    if tele[col].dtypes =='object':
        tele[col] = preprocessing.LabelEncoder().fit_transform(tele[col])

# %%
tele.dtypes
# Out:
# Account_Length      int64
# Vmail_Message       int64
# Day_Mins          float64
# Eve_Mins          float64
# Night_Mins        float64
# Intl_Mins         float64
# CustServ_Calls      int64
# Churn               int32
# Intl_Plan           int32
# Vmail_Plan          int32
# Day_Calls           int64
# Day_Charge        float64
# Eve_Calls           int64
# Eve_Charge        float64
# Night_Calls         int64
# Night_Charge      float64
# Intl_Calls          int64
# Intl_Charge       float64
# State               int32
# Area_Code           int64
# Phone               int32
# dtype: object

# %%
tele.nunique()
# Out:
# Account_Length     212
# Vmail_Message       46
# Day_Mins          1667
# Eve_Mins          1611
# Night_Mins        1591
# Intl_Mins          162
# CustServ_Calls      10
# Churn                2
# Intl_Plan            2
# Vmail_Plan           2
# Day_Calls          119
# Day_Charge        1667
# Eve_Calls          123
# Eve_Charge        1440
# Night_Calls        120
# Night_Charge       933
# Intl_Calls          21
# Intl_Charge        162
# State               51
# Area_Code            3
# Phone             3333
# dtype: int64

# %% [markdown]
# ###### Drop unnecessary features - Phone, Area Code and State are unimportant columns in the context of our problem, I drop these.

# %%
tele = tele.drop(['State', 'Area_Code', 'Phone'], axis = 1)

# %%
tele.head()
# Out:
#    Account_Length  Vmail_Message  Day_Mins  Eve_Mins  Night_Mins  Intl_Mins  \
# 0             128             25     265.1     197.4       244.7       10.0
# 1             107             26     161.6     195.5       254.4       13.7
# 2             137              0     243.4     121.2       162.6       12.2
# 3              84              0     299.4      61.9       196.9        6.6
# 4              75              0     166.7     148.3       186.9       10.1
#
#    CustServ_Calls  Churn  Intl_Plan  Vmail_Plan  Day_Calls  Day_Charge  \
# 0               1      0          0           1        110       45.07
# 1               1      0          0           1        123       27.47
# 2               0      0          0           0        114       41.38
# 3               2      0          1           0         71       50.90
# 4               3      0          1           0        113       28.34
#
#    Eve_Calls  Eve_Charge  Night_Calls  Night_Charge  Intl_Calls  Intl_Charge
# 0         99       16.78           91         11.01           3         2.70
# 1        103       16.62          103         11.45           3         3.70
# 2        110       10.30          104          7.32           5         3.29
# 3         88        5.26           89          8.86           7         1.78
# 4        122       12.61          121          8.41           3         2.73

# %% [markdown]
# ###### In order to prepare a model, I will first take a look at the features and finalize the important features using which I will perform the churn prediction

# %% [markdown]
# ###### Drop highly correlated features as they do not provide additional information to the model.

# %%
corr_matrix = tele.corr()
corr_matrix.style.background_gradient()
# Out:
# <style type="text/css">
# #T_b0adf_row0_col0, #T_b0adf_row1_col1, #T_b0adf_row2_col2, #T_b0adf_row2_col11, #T_b0adf_row3_col3, #T_b0adf_row3_col13, #T_b0adf_row4_col4, #T_b0adf_row4_col15, #T_b0adf_row5_col5, #T_b0adf_row5_col17, #T_b0adf_row6_col6, #T_b0adf_row7_col7, #T_b0adf_row8_col8, #T_b0adf_row9_col9, #T_b0adf_row10_col10, #T_b0adf_row11_col2, #T_b0adf_row11_col11, #T_b0adf_row12_col12, #T_b0adf_row13_col3, #T_b0adf_row13_col13, #T_b0adf_row14_col14, #T_b0adf_row15_col4, #T_b0adf_row15_col15, #T_b0adf_row16_col16, #T_b0adf_row17_col5, #T_b0adf_row17_col17 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_b0adf_row0_col1, #T_b0adf_row2_col8, #T_b0adf_row6_col9, #T_b0adf_row11_col8, #T_b0adf_row12_col1 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T
{
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_b0adf_row3_col1, #T_b0adf_row4_col9, #T_b0adf_row8_col9, #T_b0adf_row12_col7, #T_b0adf_row13_col1, #T_b0adf_row14_col7, #T_b0adf_row15_col9, #T_b0adf_row16_col9 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_b0adf_row3_col7, #T_b0adf_row13_col7 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_b0adf_row3_col8, #T_b0adf_row4_col10, #T_b0adf_row10_col4, #T_b0adf_row10_col15, #T_b0adf_row13_col8, #T_b0adf_row14_col16, #T_b0adf_row15_col10, #T_b0adf_row16_col5, #T_b0adf_row16_col7, #T_b0adf_row16_col8, #T_b0adf_row16_col17 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_b0adf_row3_col9, #T_b0adf_row7_col3, #T_b0adf_row7_col13, #T_b0adf_row10_col7, #T_b0adf_row13_col9 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_b0adf_row3_col10, #T_b0adf_row3_col12, #T_b0adf_row4_col5, #T_b0adf_row4_col8, #T_b0adf_row4_col17, #T_b0adf_row5_col2, #T_b0adf_row5_col11, #T_b0adf_row6_col2, #T_b0adf_row6_col10, #T_b0adf_row6_col11, #T_b0adf_row7_col1, #T_b0adf_row7_col9, #T_b0adf_row7_col16, #T_b0adf_row8_col4, #T_b0adf_row8_col6, #T_b0adf_row8_col15, #T_b0adf_row9_col7, #T_b0adf_row10_col3, #T_b0adf_row10_col13, #T_b0adf_row10_col14, #T_b0adf_row13_col10, #T_b0adf_row13_col12, #T_b0adf_row14_col0, #T_b0adf_row14_col5, #T_b0adf_row14_col10, #T_b0adf_row14_col17, #T_b0adf_row15_col5, #T_b0adf_row15_col8, #T_b0adf_row15_col17, #T_b0adf_row17_col2, #T_b0adf_row17_col11 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_b0adf_row4_col7, #T_b0adf_row15_col7 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_b0adf_row5_col7, #T_b0adf_row17_col7 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_b0adf_row5_

# %%
tele.drop(['Vmail_Plan', 'Day_Charge', 'Eve_Charge', 'Night_Charge', 'Intl_Charge'], axis = 1, inplace = True)

# %%
corr_matrix = tele.corr()
corr_matrix.style.background_gradient()
# Out:
# <style type="text/css">
# #T_eae77_row0_col0, #T_eae77_row1_col1, #T_eae77_row2_col2, #T_eae77_row3_col3, #T_eae77_row4_col4, #T_eae77_row5_col5, #T_eae77_row6_col6, #T_eae77_row7_col7, #T_eae77_row8_col8, #T_eae77_row9_col9, #T_eae77_row10_col10, #T_eae77_row11_col11, #T_eae77_row12_col12 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_eae77_row0_col1, #T_eae77_row2_col8, #T_eae77_row10_col1 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_eae77_row0_col2, #T_eae77_row0_col3, #T_eae77_row0_col4, #T_eae77_row1_col2, #T_eae77_row1_col5, #T_eae77_row2_col0, #T_eae77_row3_col4, #T_eae77_row4_col2, #T_eae77_row4_col6, #T_eae77_row5_col4, #T_eae77_row5_col6, #T_eae77_row6_col4, #T_eae77_row6_col10, #T_eae77_row8_col10, #T_eae77_row9_col10, #T_eae77_row11_col10, #T_eae77_row12_col4, #T_eae77_row12_col11 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_eae77_row0_col5, #T_eae77_row1_col11, #T_eae77_row2_col10, #T_eae77_row3_col11, #T_eae77_row7_col11, #T_eae77_row8_col9, #T_eae77_row10_col4, #T_eae77_row10_col5, #T_eae77_row10_col6, #T_eae77_row10_col9, #T_eae77_row10_col11, #T_eae77_row12_col3, #T_eae77_row12_col9 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T
{
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_eae77_row5_col7 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_eae77_row5_col8, #T_eae77_row9_col1 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_eae77_row5_col12 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_eae77_row6_col7 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_eae77_row7_col2 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_eae77_row7_col3 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_eae77_row7_col6 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_eae77_row7_col8 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_eae77_row8_col1, #T_eae77_row10_col7 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_eae77_row8_col7 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# </style>
# <table id="T_eae77">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eae77_level0_col0" class="col_heading level0 col0" >Account_Length</th>
#       <th id="T_eae77_level0_col1" class="col_heading level0 col1" >Vmail_Message</th>
#       <th id="T_eae77_level0_col2" class="col_heading level0 col2" >Day_Mins</th>
#       <th id="T_eae77_level0_col3" class="col_heading level0 col3" >Eve_Mins</th>
#       <th id="T_eae77_level0_col4" class="col_heading level0 col4" >Night_Mins</th>
#       <th id="T_eae77_level0_col5" class="col_heading level0 col5" >Intl_Mins</th>
#       <th id="T_eae77_level0_col6" class="col_heading level0 col6" >CustServ_Calls</th>
#       <th id="T_eae77_level0_col7" class="col_heading level0 col7" >Churn</th>
#       <th id="T_eae77_level0_col8" class="col_heading level0 col8" >Intl_Plan</th>
#       <th id="T_eae77_level0_col9" class="col_heading level0 col9" >Day_Calls</th>
#       <th id="T_eae77_level0_col10" class="col_heading level0 col10" >Eve_Calls</th>
#       <th id="T_eae77_level0_col11" class="col_heading level0 col11" >Night_Calls</th>
#       <th id="T_eae77_level0_col12" class="col_heading level0 col12" >Intl_Calls</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eae77_level0_row0" class="row_heading level0 row0" >Account_Length</th>
#       <td id="T_eae77_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_eae77_row0_col1" class="data row0 col1" >-0.004628</td>
#       <td id="T_eae77_row0_col2" class="data row0 col2" >0.006216</td>
#       <td id="T_eae77_row0_col3" class="data row0 col3" >-0.006757</td>
#       <td id="T_eae77_row0_col4" class="data row0 col4" >-0.008955</td>
#       <td id="T_eae77_row0_col5" class="data row0 col5" >0.009514</td>
#       <td id="T_eae77_row0_col6" class="data row0 col6" >-0.003796</td>
#       <td id="T_eae77_row0_col7" class="data row0 col7" >0.016541</td>
#       <td id="T_eae77_row0_col8" class="data row0 col8" >0.024735</td>
#       <td id="T_eae77_row0_col9" class="data row0 col9" >0.038470</td>
#       <td id="T_eae77_row0_col10" class="data row0 col10" >0.019260</td>
#       <td id="T_eae77_row0_col11" class="data row0 col11" >-0.013176</td>
#       <td id="T_eae77_row0_col12" class="data row0 col12" >0.020661</td>
#     </tr>
#     <tr>
#       <th id="T_eae77_level0_row1" class="row_heading level0 row1" >Vmail_Message</th>
#       <td id="T_eae77_row1_col0" class="data row1 col0" >-0.004628</td>
#       <td id="T_eae77_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_eae77_row1_col2" class="data row1 col2" >0.000778</td>
#       <td id="T_eae77_row1_col3" class="data row1 col3" >0.017562</td>
#       <td id="T_eae77_row1_col4" class="data row1 col4" >0.007681</td>
#       <td id="T_eae77_row1_col5" class="data row1 col5" >0.002856</td>
#       <td id="T_eae77_row1_col6" class="data row1 col6" >-0.013263</td>
#       <td i

# %%
X = tele.drop('Churn', axis = 1)
y = tele['Churn']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)
